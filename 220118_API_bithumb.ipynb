# %%
pip install pybithumb
# Out:
# Collecting pybithumb
#   Downloading pybithumb-1.0.21-py3-none-any.whl (9.9 kB)
# Collecting requests
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: pandas in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pybithumb) (1.3.5)
# Collecting websockets
#   Downloading websockets-10.1-cp38-cp38-win_amd64.whl (97 kB)
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: bs4 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pybithumb) (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from bs4->pybithumb) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from beautifulsoup4->bs4->pybithumb) (2.3.1)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp38-cp38-win_amd64.whl (210 kB)
# Requirement already satisfied: pytz in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from datetime->pybithumb) (2021.3)
# Requirement already satisfied: six>=1.9 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from html5lib->pybithumb) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from html5lib->pybithumb) (0.5.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pandas->pybithumb) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pandas->pybithumb) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from requests->pybithumb) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from requests->pybithumb) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from requests->pybithumb) (1.26.8)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# Requirement already satisfied: setuptools in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from zope.interface->datetime->pybithumb) (58.0.4)
# Installing collected packages: zope.interface, charset-normalizer, websockets, requests, html5lib, datetime, pybithumb
# Successfully installed charset-normalizer-2.0.10 datetime-4.3 html5lib-1.1 pybithumb-1.0.21 requests-2.27.1 websockets-10.1 zope.interface-5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pybithumb as pb

# %%
tickers= pb.get_tickers()
tickers
# Out:
# ['BTC',
#  'ETH',
#  'LTC',
#  'ETC',
#  'XRP',
#  'BCH',
#  'QTUM',
#  'BTG',
#  'EOS',
#  'ICX',
#  'TRX',
#  'ELF',
#  'OMG',
#  'KNC',
#  'GLM',
#  'ZIL',
#  'WAXP',
#  'POWR',
#  'LRC',
#  'STEEM',
#  'STRAX',
#  'ZRX',
#  'REP',
#  'XEM',
#  'SNT',
#  'ADA',
#  'CTXC',
#  'BAT',
#  'WTC',
#  'THETA',
#  'LOOM',
#  'WAVES',
#  'TRUE',
#  'LINK',
#  'ENJ',
#  'VET',
#  'MTL',
#  'IOST',
#  'TMTG',
#  'QKC',
#  'ATOLO',
#  'AMO',
#  'BSV',
#  'ORBS',
#  'TFUEL',
#  'VALOR',
#  'CON',
#  'ANKR',
#  'MIX',
#  'CRO',
#  'FX',
#  'CHR',
#  'MBL',
#  'MXC',
#  'FCT',
#  'TRV',
#  'DAD',
#  'WOM',
#  'SOC',
#  'BOA',
#  'FLETA',
#  'SXP',
#  'COS',
#  'APIX',
#  'EL',
#  'BASIC',
#  'HIVE',
#  'XPR',
#  'VRA',
#  'FIT',
#  'EGG',
#  'BORA',
#  'ARPA',
#  'CTC',
#  'APM',
#  'CKB',
#  'AERGO',
#  'ANW',
#  'CENNZ',
#  'EVZ',
#  'CYCLUB',
#  'SRM',
#  'QTCON',
#  'UNI',
#  'YFI',
#  'UMA',
#  'AAVE',
#  'COMP',
#  'REN',
#  'BAL',
#  'RSR',
#  'NMR',
#  'RLC',
#  'UOS',
#  'SAND',
#  'GOM2',
#  'RINGX',
#  'BEL',
#  'OBSR',
#  'ORC',
#  'POLA',
#  'AWO',
#  'ADP',
#  'DVI',
#  'GHX',
#  'MIR',
#  'MVC',
#  'BLY',
#  'WOZX',
#  'ANV',
#  'GRT',
#  'MM',
#  'BIOT',
#  'XNO',
#  'SNX',
#  'SOFI',
#  'COLA',
#  'NU',
#  'OXT',
#  'LINA',
#  'MAP',
#  'AQT',
#  'WIKEN',
#  'CTSI',
#  'MANA',
#  'LPT',
#  'MKR',
#  'SUSHI',
#  'ASM',
#  'PUNDIX',
#  'CELR',
#  'LF',
#  'ARW',
#  'MSB',
#  'RLY',
#  'OCEAN',
#  'BFC',
#  'ALICE',
#  'COTI',
#  'CAKE',
#  'BNT',
#  'XVS',
#  'CHZ',
#  'AXS',
#  'DAI',
#  'MATIC',
#  'BAKE',
#  'VELO',
#  'BCD',
#  'XLM',
#  'GXC',
#  'VSYS',
#  'IPX',
#  'WICC',
#  'ONT',
#  'LUNA',
#  'AION',
#  'META',
#  'KLAY',
#  'ONG',
#  'ALGO',
#  'JST',
#  'XTZ',
#  'MLK',
#  'WEMIX',
#  'DOT',
#  'ATOM',
#  'SSX',
#  'TEMCO',
#  'HIBS',
#  'BURGER',
#  'DOGE',
#  'KSM',
#  'CTK',
#  'XYM',
#  'BNB',
#  'NFT',
#  'SUN',
#  'XEC',
#  'PCI',
#  'SOL',
#  'MED',
#  '1INCH',
#  'BOBA',
#  'GALA',
#  'BTT']

# %%
price = pb.get_current_price('XRP')
price
# Out:
# 902.3

# %%
#tickers = pb.get_tickers()
#tickers = ['BTC','ETH','XRP','ADA']

#for ticker in tickers:
    #price pb.get_current_price(ticker)
   # print(ticker,price)

# %%
import sys # 시스템 접근
from PyQt5.QtWidgets import *
from PyQt5 import uic            # pyqt 사용 라이브러리

form_class = uic.loadUiType("mywindow.ui")[0] # pyqt 만들어온 창 열기

class MyWindow(QMainWindow, form_class):
    def __init__(self):
        super().__init__()
        self.setupUi(self)
        self.pushButton.clicked.connect(self.btn_clicked)
        
    def btn_clicked(self):
        print("버튼 클릭")
        
app = QApplication(sys.argv)
window = MyWindow()   # 객체 생성
window.show()         # 객체로 창 띄우기
app.exec_()           # 창을 계속 유지

# %%
# !pip3 install pyqt5
import sys # 시스템 접근
from PyQt5.QtWidgets import *
from PyQt5 import uic            # pyqt 사용 라이브러리
import pybithumb as pb

form_class = uic.loadUiType("mywindow.ui")[0] # pyqt 만들어온 창 열기

class MyWindow(QMainWindow, form_class):
    def __init__(self):
        super().__init__()
        self.setupUi(self)
        self.pushButton.clicked.connect(self.inquiry)
        
    def inquiry(self):
        price = pb.get_current_price("BTC")
        price2 = pb.get_current_price("ETH")
        self.lineEdit.setText(str(price))
        self.lineEdit_2.setText(str(price2))
        
app = QApplication(sys.argv)
window = MyWindow()   # 객체 생성
window.show()         # 객체로 창 띄우기
app.exec_()           # 창을 계속 유지
# Out:
# Requirement already satisfied: pyqt5 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (5.15.6)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pyqt5) (12.9.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\kwon haemin\anaconda3\envs\python38\lib\site-packages (from pyqt5) (5.15.2)
# 0
